# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"data\clean.csv")
data.head()
# Out:
#    Unnamed: 0        Name  Age  Annual_Income Purchase_Car
# 0           0   Person_10   30         601896          Yes
# 1           1   Person_43   21         578480          Yes
# 2           2   Person_34   40         898376          Yes
# 3           3  Person_312   22         354162           No
# 4           4  Person_273   29         377738           No

# %%
sns.histplot(data,x='Age')
plt.show()

# %%
sns.histplot(data,x='Age')
plt.show()

# %%
sns.boxplot(data["Annual_Income"])
plt.show()

# %%
data["Purchase_Car"].value_counts()
# Out:
# Purchase_Car
# Yes    195
# No     195
# Name: count, dtype: int64
